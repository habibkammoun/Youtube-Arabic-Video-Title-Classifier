# %% [markdown]
# # Packages Import

# %%
import arabic_reshaper
import matplotlib.pyplot as plt
import nltk
import os
import pandas as pd
import pickle
import re
from bidi.algorithm import get_display
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from stop_words import get_stop_words
from wordcloud import WordCloud
from hunspell import Hunspell

# %% [markdown]
# # 1 - Business & data Understanding

# %%
data = pd.read_excel("new_data1.xlsx")
data.head()
# Out:
#             id                                              title  \
# 0  vFb-NHhy27o                          Fornite or Call duty 🤔🤔🤔🤔
# 1  Svm9yokQoJs                                       كولف ديوتي 🤫
# 2  MFFDr8MFHuo  دين الاسلام دين الوسط  كيف وسط بين ماذا وماذا ...
# 3  nR3sHfDGhwU            لعبة ثلاجة وفريزر - العاب اطفال تعليمية
# 4  2Y9QLffnl6g  Have you ever seen this animal up close? This ...
#
#   category_name
# 0         ألعاب
# 1         ألعاب
# 2         الدين
# 3         ألعاب
# 4        وثائقي

# %%
category_counts = data.category_name.value_counts()
category_names = category_counts.index.tolist()
category_values = category_counts.values.tolist()
category_counts
# Out:
# category_name
# الدين     3438
# ألعاب     2923
# وثائقي    2725
# Name: count, dtype: int64

# %% [markdown]
# This dataset includes :
#    <br> &emsp; * 9086 samples ;
#    <br> &emsp; * 3 classes which are وثائقي , ألعاب and الدين
#    <br> &emsp; * Text located at the column with index of 2

# %%
# Reshape and reorder the Arabic labels for proper display
reshaped_labels = [get_display(arabic_reshaper.reshape(label)) for label in category_names]
# Plot with bars
plt.bar(reshaped_labels, category_values)
plt.xlabel('Category Name')
plt.ylabel('Counts')
plt.xticks(rotation=45)
plt.show()

# %%
titles = data['title']  # Notice the double brackets
labels = data['category_name']
tiddy_features=[]
for i in titles: 
    # Remove special characters, retain Arabic letters and numbers
    tmp = re.sub(r'[^\u0620-\u063F\u0641-\u064A\u0660-\u0669]', ' ', str(i))
    # Remove numerical numbers
    tmp = re.sub(r'\d+', ' ', tmp)
    # Remove multiple spaces
    tmp = re.sub(r'\s+', ' ', tmp).strip()
    tiddy_features.append(tmp)
print(tiddy_features)
# Assuming 'labels' is a pandas Series, convert it to a list for manipulation

# Use zip to pair up tiddy_features and labels_list entries
paired_features_labels = list(zip(tiddy_features, labels))

# Filter out the pairs where the feature is an empty string
paired_features_labels = [(feature, label) for feature, label in paired_features_labels if feature]

# Unzip the pairs back into separate lists
tiddy_features, labels_list = zip(*paired_features_labels)

# Convert tuples back to lists (if you need lists)
tiddy_features = list(tiddy_features)
labels_list = list(labels_list)
# Out:
# ['', 'كولف ديوتي', 'دين الاسلام دين الوسط كيف وسط بين ماذا وماذا الشيخ الشعراوى', 'لعبة ثلاجة وفريزر العاب اطفال تعليمية', '', 'لعبه كولف ديوتي جلد', 'أكبر السفن في العالم الشرق الوثائقية', '', 'لعبت قيم فورت نايت كامل باصغر كيبورد في العالم', 'وثائقي سباق التسلح حاملات الطائرات', 'اكتشاف المجهول الأمازون خفايا مخلوقات الأمازون الجزء الأول', 'وثائقي سطانلي متورط في تهريب الممنوعات', 'دلائل عقلية تثبت أن دين الاسلام هو دين الحق', 'شروط الزكاة وزكاة الحرث كتاب الزكاة شرح ابن عاشر نايف آل الشيخ مبارك', 'ما حكم إرسال أموال الزكاة لأهل غزة الدكتور محمد الصغير ي جيب', 'التلفزيون العربي وثائقي رحلة الموت', 'سباق دراجات ألعاب', 'الاحد الاول من الصوم الكبير احد الكنوز لا تكنزوا ابونا لوقا سيداروس', 'تعريب لعبة فار كراي بريميل ب الترجمه العربي الكامله حورات و نصوص و قوام', 'اساسيات الحياة الروحية الصوم ابونا داود لمعي اجتماع خدام الانبا ابرام الثلاثاء مارس', '', 'هل الرعاف يفسد الصوم الشيخ وليد السعيدان الرعاف', '', 'السعوديه عام م هجري فيلم وثائقي إنتاج أوروبي عيد الحربي رحمه الله وعبدالله الحربي', '', 'الرئيس التونسي الدستور الجديد لن ينص على الإسلام دين ا للدولة وإنما دين للأمة', 'لقاء من هل الدين يمنع وجوب الزكاة الشيخ ابن عثيمين مشروع كبار العلماء', 'كولف ديوتي', 'سورة البقرة الشيخ عبد الرحمن السديس القران الكريم مباشر', 'خطبة الجمعة بعنوان الإسلام دين الإسلام الشيخ عادل بن مرزوق الحارثي', 'وثائقي لحظات قبل الكارثة بيرل هاربر', 'الغوريلا العملاقة الحيوانات المفترسة حيوانات الغابة وثائقي وثائقي الحيوانات', 'وثائقي الحرب العالمية الأولى الحلقة الثانية', 'سؤال جريء هل الإسلام دين ودولة', 'وثائقى أنثى الذئاب ملكة يلوستون عالم الحيوانات المفترسة', 'ابكاليبس وثائقي الحرب العالمية الثانية ح ج', 'ناستيا تتظاهر باللعب في مزرعه مع جرارات وحيوانات المزرعة لعب للأطفال', 'كولف ديوتي موبايل', 'وثائقي ص وتي أبوكاليبس الحرب العالمية التاني', 'وثائقي', 'اول مره العب كونتر سترايك شوفو شو يلي صار', 'فار كراي سرقة الدبابة', 'دين و طين مسلسل المخلوق الأعظم الحلقة الأولى', 'وثائقي الحرب العالمية الاولى الحلقة', 'ستعشقون صلاتكم بعد مشاهدة هذا الفيديو الصلاة الإسلامية الدكتور علي منصور كيالي', 'وحش السماء الروسي وثائقي سوخوي صديقة بوتين', 'فار كراي نقطة تفتيش ديامانتي الشرقية', '', 'السوخوي المصرية أقوي طائرة في القوات الجوية ممنوعة من الطيران وثائقي خاص للمجموعة مؤرخين', 'فار كراي حمايه المعبد من جيش الامبراطور', 'وثائقي امن المطارات موسم جديد مطار فيوميتشينو روما ايطاليا', 'امكامل مات الناس موتوني في يوم عيد ميلادي ليييش', 'دين و طين أين الله', '', 'هدف عالمي برأس لترجي الرياضي التونسي الترجي تونس المغرب الجزائر ألعاب', 'الصلاة الإلهية الكبرى لا إله إلا أنت سبحانك إني كنت من الظالمين', 'بث مباشر تختيم قصة كول اوف ديوتي مودرن وارفير كاملة في جلسة وحدة', 'هل الإسلام دين الحق مناظرة', 'دروس رمضانية كيفية الخشوع في الصلاة والأسباب المعينة على ذلك', 'وثائقي أسطول صيد السمك في المغرب موريتانيا وإستغلال الثرواث العربية', 'الحيوانات الأكثر فتكا في أفريقيا الغابات عرض جديد', 'شفا وصلت لأخر مرحلة في', 'كونتر سترايك لقطات مميزة', 'ألغاز المتاحف تشارلز ديكنز بطل قومي الحلقة الشرق ديسكفري', 'لعبة سيارة الشرطة البرازيل العاب سيارات العاب اندرويد محاكي ألقياده العاب سيارات', 'مجموعة فاغنر من يشرف على مرتزقة روسيا في ليبيا وثائقي', 'وثائقي المغاربة في الجزائر هروب نحو الحياة', 'تسللت ساعة على اخطر قطار في العالم مع', '', '', 'الشيخ عثمان الخميس عثمان الخميس فتاوى العلماء فتاوى الدروس الصلاة', 'العبة التي تشبه كولف ديوتي ورزون', 'وصلت راوند في لعبة زومبي مايموت', 'أهمية الصلاة المدرسة', 'نشيد أركان الإسلام الخمسة بدون موسيقى بدون إيقاع', 'يستفتونك كيفية الزكاة على المضاربين والمستثمرين في مجال الأسهم مع الشيخ د سعد الخثلان', 'رجال أعمال بيلاعبوا الفقراء ألعاب واللي بيخسر بيقتلوه من باب التسلية لعبة الحبار', 'الشيخ الشعراوي الصلاة الله اللهم صل وسلم على نبينا محمد', '', '', 'نشيد الصلاة التربية الاسلامية للصف الاول ابتدائي', 'الأصول الثلاثة الأصل الثاني معرفة دين الإسلام بالأدلة المرتبة الثانية الإيمان', 'بروفات فرقة نغم اللإنشادية مع المنشد محمد الغزالي أقبل شهر الصوم', 'زكاة الأنعام', 'وقت الصلاة ماريا نظمي كورال مارإفرام السرياني', 'وثائقي في قلب قبيلة الماساي أول حارستين للغابات في كينيا وثائقية دي دبليو', 'أناشيد ورسوم إسلامية الصيام ممتع', 'ياسر ممدوح معلومة عن الص ...

# %%
# Combine all text items into a single string and reshape
combined_text = ' '.join(tiddy_features)
reshaped_text = arabic_reshaper.reshape(combined_text)
bidi_text = get_display(reshaped_text)  # For right-to-left (RTL) languages

# Define a font that supports Arabic characters
font_path = "C:\\Windows\\Fonts\\arial.ttf"  # Escape backslashes for Windows paths

# Generate a word cloud image
wordcloud = WordCloud(width=800, height=400, background_color='white', font_path=font_path).generate(bidi_text)

# Display the word cloud using matplotlib
plt.figure(figsize=(15, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
arabic_stop_words = get_stop_words('arabic')

vectorizer = TfidfVectorizer(max_features=2000, min_df=7, max_df=0.8, stop_words=arabic_stop_words)
X=vectorizer.fit_transform(tiddy_features).toarray()

# %%
X_train,X_test,y_train,y_test=train_test_split(X,labels_list,test_size=0.2)

# %%
#Inialisation of ML Algorithms
model=MLPClassifier(hidden_layer_sizes=(100,150),activation='logistic',solver='adam')
gnb = GaussianNB()
linear_sm=SVC(kernel='linear',probability=True)
rbf_svm=SVC(kernel='rbf',probability=True)
sgd_svm=SVC(kernel='sigmoid',probability=True)
poly_svm =SVC(kernel='poly',degree=2,probability=True)

# %%
#Training of Ml Algorithms
model.fit(X_train,y_train)
gnb.fit(X_train,y_train)
linear_sm.fit(X_train,y_train)
rbf_svm.fit(X_train,y_train)
sgd_svm.fit(X_train,y_train)
poly_svm.fit(X_train,y_train)
# Out:
# SVC(degree=2, kernel='poly', probability=True)

# %%
#Predection
y_pred_model=model.predict(X_test)
y_pred_gnb=gnb.predict(X_test)
y_pred_linear_sm=linear_sm.predict(X_test)
y_pred_rbf_svm=rbf_svm.predict(X_test)
y_pred_sgd_svm=sgd_svm.predict(X_test)
y_pred_poly_svm=poly_svm.predict(X_test)

# %%
print("**************** Performance Evaluation of MLPClassifier  ****************")
print(classification_report(y_test,y_pred_model))
print()
print("****************    Performance Evaluation of NaiveBayes  ****************")
print(classification_report(y_test,y_pred_gnb))
print()
print("****************    Performance Evaluation of Linear SVM  ****************")
print(classification_report(y_test,y_pred_linear_sm))
print()
print("****************    Performance Evaluation of RBF SVM     ****************")
print(classification_report(y_test,y_pred_rbf_svm))
print()
print("****************    Performance Evaluation of SGD SVM     ****************")
print(classification_report(y_test,y_pred_sgd_svm))
print()
print("**************** Performance Evaluation of Polynomial SVM ****************")
print(classification_report(y_test,y_pred_poly_svm))
print()
# Out:
# **************** Performance Evaluation of MLPClassifier  ****************
#               precision    recall  f1-score   support
#
#        ألعاب       0.98      0.95      0.96       473
#        الدين       0.97      1.00      0.98       638
#       وثائقي       0.97      0.97      0.97       519
#
#     accuracy                           0.97      1630
#    macro avg       0.97      0.97      0.97      1630
# weighted avg       0.97      0.97      0.97      1630
#
#
# ****************    Performance Evaluation of NaiveBayes  ****************
#               precision    recall  f1-score   support
#
#        ألعاب       0.92      0.91      0.92       473
#        الدين       0.94      0.98      0.96       638
#       وثائقي       0.95      0.90      0.92       519
#
#     accuracy                           0.93      1630
#    macro avg       0.93      0.93      0.93      1630
# weighted avg       0.94      0.93      0.93      1630
#
#
# ****************    Performance Evaluation of Linear SVM  ****************
#               precision    recall  f1-score   support
#
#        ألعاب       0.98      0.96      0.97       473
#        الدين       0.99      0.99      0.99       638
#       وثائقي       0.96      0.98      0.97       519
#
#     accuracy                           0.98      1630
#    macro avg       0.98      0.98      0.98      1630
# weighted avg       0.98      0.98      0.98      1630
#
#
# ****************    Performance Evaluation of RBF SVM     ****************
#               precision    recall  f1-score   support
#
#        ألعاب       0.97      0.97      0.97       473
#        الدين       0.99      0.99      0.99       638
#       وثائقي       0.98      0.97      0.98       519
#
#     accuracy                           0.98      1630
#    macro avg       0.98      0.98      0.98      1630
# weighted avg       0.98      0.98      0.98      1630
#
#
# ****************    Performance Evaluation of SGD SVM     ****************
#               precision    recall  f1-score   support
#
#        ألعاب       0.97      0.95      0.96       473
#        الدين       0.99      0.99      0.99       638
#       وثائقي       0.95      0.97      0.96       519
#
#     accuracy                           0.97      1630
#    macro avg       0.97      0.97      0.97      1630
# weighted avg       0.97      0.97      0.97      1630
#
#
# **************** Performance Evaluation of Polynomial SVM ****************
#               precision    recall  f1-score   support
#
#        ألعاب       0.99      0.93      0.96       473
#        الدين       0.98      0.99      0.98       638
#       وثائقي       0.95      0.98      0.96       519
#
#     accuracy                           0.97      1630
#    macro avg       0.97      0.97      0.97      1630
# weighted avg       0.97      0.97      0.97      1630

# %%
pickle.dump(vectorizer,open('vectorizer.pickle',"wb"))
pickle.dump(rbf_svm,open('bestModel.pickle',"wb"))

# %%
# Use Continuous Bag of Words for feature extraction
vectorizer = CountVectorizer(max_features=2000, min_df=3, max_df=0.8, stop_words=arabic_stop_words)
X = vectorizer.fit_transform(tiddy_features).toarray()

# %%
# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, labels_list, test_size=0.2)

# %%
# Training of ML Algorithms
model.fit(X_train, y_train)
gnb.fit(X_train, y_train)
linear_sm.fit(X_train, y_train)
rbf_svm.fit(X_train, y_train)
sgd_svm.fit(X_train, y_train)
poly_svm.fit(X_train, y_train)
# Out:
# SVC(degree=2, kernel='poly', probability=True)

# %%
# Prediction
y_pred_model = model.predict(X_test)
y_pred_gnb = gnb.predict(X_test)
y_pred_linear_sm = linear_sm.predict(X_test)
y_pred_rbf_svm = rbf_svm.predict(X_test)
y_pred_sgd_svm = sgd_svm.predict(X_test)
y_pred_poly_svm = poly_svm.predict(X_test)

# %%
# Performance Evaluation
print("**************** Performance Evaluation of MLPClassifier ****************")
print(classification_report(y_test, y_pred_model))
print()
print("**************** Performance Evaluation of NaiveBayes ****************")
print(classification_report(y_test, y_pred_gnb))
print()
print("**************** Performance Evaluation of Linear SVM ****************")
print(classification_report(y_test, y_pred_linear_sm))
print()
print("**************** Performance Evaluation of RBF SVM ****************")
print(classification_report(y_test, y_pred_rbf_svm))
print()
print("**************** Performance Evaluation of SGD SVM ****************")
print(classification_report(y_test, y_pred_sgd_svm))
print()
print("**************** Performance Evaluation of Polynomial SVM ****************")
print(classification_report(y_test, y_pred_poly_svm))
# Out:
# **************** Performance Evaluation of MLPClassifier ****************
#               precision    recall  f1-score   support
#
#        ألعاب       0.96      0.98      0.97       493
#        الدين       0.99      0.99      0.99       632
#       وثائقي       0.98      0.96      0.97       505
#
#     accuracy                           0.98      1630
#    macro avg       0.98      0.98      0.98      1630
# weighted avg       0.98      0.98      0.98      1630
#
#
# **************** Performance Evaluation of NaiveBayes ****************
#               precision    recall  f1-score   support
#
#        ألعاب       0.90      0.98      0.94       493
#        الدين       0.99      0.97      0.98       632
#       وثائقي       0.97      0.91      0.94       505
#
#     accuracy                           0.96      1630
#    macro avg       0.95      0.95      0.95      1630
# weighted avg       0.96      0.96      0.96      1630
#
#
# **************** Performance Evaluation of Linear SVM ****************
#               precision    recall  f1-score   support
#
#        ألعاب       0.95      0.99      0.97       493
#        الدين       1.00      0.98      0.99       632
#       وثائقي       0.98      0.96      0.97       505
#
#     accuracy                           0.98      1630
#    macro avg       0.98      0.98      0.98      1630
# weighted avg       0.98      0.98      0.98      1630
#
#
# **************** Performance Evaluation of RBF SVM ****************
#               precision    recall  f1-score   support
#
#        ألعاب       0.95      0.98      0.97       493
#        الدين       0.99      0.98      0.99       632
#       وثائقي       0.98      0.96      0.97       505
#
#     accuracy                           0.97      1630
#    macro avg       0.97      0.97      0.97      1630
# weighted avg       0.98      0.97      0.97      1630
#
#
# **************** Performance Evaluation of SGD SVM ****************
#               precision    recall  f1-score   support
#
#        ألعاب       0.96      0.98      0.97       493
#        الدين       1.00      0.98      0.99       632
#       وثائقي       0.97      0.97      0.97       505
#
#     accuracy                           0.98      1630
#    macro avg       0.97      0.98      0.98      1630
# weighted avg       0.98      0.98      0.98      1630
#
#
# **************** Performance Evaluation of Polynomial SVM ****************
#               precision    recall  f1-score   support
#
#        ألعاب       0.91      0.99      0.95       493
#        الدين       1.00      0.97      0.98       632
#       وثائقي       0.99      0.93      0.96       505
#
#     accuracy                           0.96      1630
#    macro avg       0.96      0.96      0.96      1630
# weighted avg       0.97      0.96      0.96      1630

# %%
pickle.dump(vectorizer,open('vectorizerBAG.pickle',"wb"))
pickle.dump(model,open('bestModelBAG.pickle',"wb"))
